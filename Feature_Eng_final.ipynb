# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv('Bets_Fights_Organized_v3.csv')
df2 = pd.read_csv('Fighter_Stats_at_Fight.csv')
df2.rename(columns={'fight_ID':'Fight_ID'}, inplace=True)

# %%
df.head()
# Out:
#                         Event_Name       Date      Fav_Fighter        Un_Fighter                                     Fighter_ID_Fav                                      Fighter_ID_Un Result_Fav Result_Un  Round       Round_Format                 Weight_Class  Time                Method Height_Fav Reach_Fav Stance_Fav Height_Un Reach_Un Stance_Un  Age_At_Fight_Fav_Days  Age_At_Fight_Un_Days  Age_At_Fight_Fav_Years  Age_At_Fight_Un_Years  Age_Diff_Years  Age_Diff_Days  Avg_Odds_Fav  Avg_Odds_Un  Med_Odds_Fav  Med_Odds_Un  Impld_Prob_Avg_Fav  Impld_Prob_Avg_Un  Impld_Prob_Med_Fav  Impld_Prob_Med_Un  USodds_Fav_1  USodds_Un_1  USodds_Fav_2  USodds_Un_2  USodds_Fav_3  USodds_Un_3  USodds_Fav_4  USodds_Un_4  USodds_Fav_5  USodds_Un_5  Decodds_Fav_1  Decodds_Un_1  Decodds_Fav_2  Decodds_Un_2  Decodds_Fav_3  Decodds_Un_3  Decodds_Fav_4  Decodds_Un_4  Decodds_Fav_5  Decodds_Un_5  KD_Fav  KD_Un  Pass_Fav  Pass_Un  Rev_Fav  Rev_Un Sig_Str_Fav Sig_Str_Un Sig_Str_Body_Fav Sig_Str_Body_Un  \
# ...

# %%
df2 = df2[['Name_Fighter_1', 'Name_Fighter_2', 'Fighter_1_ID','Fighter_2_ID', 'Fight_ID', 'SLpM_f1', 'SSAcc_f1',
       'SSApM_f1', 'SSDef_f1', 'TDpM_f1', 'TDAcc_f1', 
        'TDDef_f1', 'SubpM_f1', 'Time_Sec_Cum_f1', 
        'Fight_Num_f1', 'SLpM_f2', 'SSAcc_f2', 'SSApM_f2', 
       'SSDef_f2', 'TDpM_f2', 'TDAcc_f2', 'TDDef_f2', 
       'SubpM_f2', 'Time_Sec_Cum_f2', 'Fight_Num_f2']]

# %%
Merged_df = pd.merge(df, df2, how='left', on=[str('Fight_ID')])

# %%
Final_df_organized_list = []
for index, row in Merged_df.iterrows():
    if row['Fav_Fighter'].strip().lower() == row['Name_Fighter_1'].strip().lower() and row['Fighter_ID_Fav'].strip().lower() == row['Fighter_1_ID'].strip().lower() and row['Un_Fighter'].strip().lower() == row['Name_Fighter_2'].strip().lower() and row['Fighter_ID_Un'].strip().lower()==row['Fighter_2_ID'].strip().lower():
        
        
        Final_df_organized_row = {
            'Event_Name':row['Event_Name'], 'Date':row['Date'],'Fav_Fighter':row['Fav_Fighter'],
            'Un_Fighter':row['Un_Fighter'], 'Fighter_ID_Fav':row['Fighter_ID_Fav'], 'Fighter_ID_Un':row['Fighter_ID_Un'],
            'Result_Fav':row['Result_Fav'], 'Result_Un':row['Result_Un'], 'Round':row['Round'], 'Round_Format':row['Round_Format'],
            'Weight_Class':row['Weight_Class'], 'Time':row['Time'], 'Method':row['Method'], 'Height_Fav':row['Height_Fav'],
            'Reach_Fav':row['Reach_Fav'], 'Stance_Fav':row['Stance_Fav'], 'Height_Un':row['Height_Un'], 'Reach_Un':row['Reach_Un'],
            'Stance_Un':row['Stance_Un'], 'Age_At_Fight_Fav_Days':row['Age_At_Fight_Fav_Days'], 'Age_At_Fight_Un_Days':row['Age_At_Fight_Un_Days'],
            'Age_At_Fight_Fav_Years':row['Age_At_Fight_Fav_Years'], 'Age_At_Fight_Un_Years':row['Age_At_Fight_Un_Years'],
            'Age_Diff_Years':row['Age_Diff_Years'],'Age_Diff_Days':row['Age_Diff_Days'], 'Avg_Odds_Fav':row['Avg_Odds_Fav'],
            'Avg_Odds_Un':row['Avg_Odds_Un'],'Med_Odds_Fav':row['Med_Odds_Fav'], 'Med_Odds_Un':row['Med_Odds_Un'],
            'Impld_Prob_Avg_Fav':row['Impld_Prob_Avg_Fav'],'Impld_Prob_Avg_Un':row['Impld_Prob_Avg_Un'],
            'Impld_Prob_Med_Fav':row['Impld_Prob_Med_Fav'],'Impld_Prob_Med_Un':row['Impld_Prob_Med_Un'],
            'USodds_Fav_1':row['USodds_Fav_1'], 'USodds_Un_1':row['USodds_Un_1'], 'USodds_Fav_2':row['USodds_Fav_2'],
            'USodds_Un_2':row['USodds_Un_2'], 'USodds_Fav_3':row['USodds_Fav_3'], 'USodds_Un_3':row['USodds_Un_3'],
            'USodds_Fav_4':row['USodds_Fav_4'],'USodds_Un_4':row['USodds_Un_4'], 'USodds_Fav_5':row['USodds_Fav_5'],
            'USodds_Un_5':row['USodds_Un_5'],'Decodds_Fav_1':row['Decodds_Fav_1'],'Decodds_Un_1':row['Decodds_Un_1'],
            'Decodds_Fav_2':row['Decodds_Fav_2'], 'Decodds_Un_2':row['Decodds_Un_2'],'Decodds_Fav_3':row['Decodds_Fav_3'],
            'Decodds_Un_3':row['Decodds_Un_3'], 'Decodds_Fav_4':row['Decodds_Fav_4'], 'Decodds_Un_4':row['Decodds_Un_4'],
            'Decodds_Fav_5':row['Decodds_Fav_5'],'Decodds_Un_5':row['Decodds_Un_5'], 'KD_Fav':row['KD_Fav'], 'KD_Un':row['KD_Un'],
            'Pass_Fav':row['Pass_Fav'], 'Pass_Un':row['Pass_Un'], 'Rev_Fav':row['Rev_Fav'], 'Rev_Un':row['Rev_Un'],
            'Sig_Str_Fav':row['Sig_Str_Fav'],'Sig_Str_Un':row['Sig_Str_Un'], 'Sig_Str_Body_Fav':row['Sig_Str_Body_Fav'],
            'Sig_Str_Body_Un':row['Sig_Str_Body_Un'], 'Sig_Str_Clinch_Fav':row['Sig_Str_Clinch_Fav'],
            'Sig_Str_Clinch_Un':row['Sig_Str_Clinch_Un'], 'Sig_Str_Distance_Fav':row['Sig_Str_Distance_Fav'],
            'Sig_Str_Distance_Un':row['Sig_Str_Distance_Un'],'Sig_Str_Ground_Fav':row['Sig_Str_Ground_Fav'],
            'Sig_Str_Ground_Un':row['Sig_Str_Ground_Un'], 'Sig_Str_Head_Fav':row['Sig_Str_Head_Fav'],
            'Sig_Str_Head_Un':row['Sig_Str_Head_Un'], 'Sig_Str_Leg_Fav':row['Sig_Str_Leg_Fav'], 'Sig_Str_Leg_Un':row['Sig_Str_Leg_Un'],
            'Sig_Str_Pct_Fav':row['Sig_Str_Pct_Fav'], 'Sig_Str_Pct_Un':row['Sig_Str_Pct_Un'], 'Sub_Att_Fav':row['Sub_Att_Fav'],
            'Sub_Att_Un':row['Sub_Att_Un'], 'TD_Fav':row['TD_Fav'], 'TD_Un':row['TD_Un'], 'TD_Pct_Fav':row['TD_Pct_Fav'],
            'TD_Pct_Un':row['TD_Pct_Un'], 'Total_Str_Fav':row['Total_Str_Fav'], 'Total_Str_Un':row['Total_Str_Un'], 
            
            'SLpM_Fav':row['SLpM_f1'], 'SSAcc_Fav':row['SSAcc_f1'], 'SSApM_Fav':row['SSApM_f1'], 'SSDef_Fav':row['SSDef_f1'],
            'TDpM_Fav':row['TDpM_f1'], 'TDAcc_Fav':row['TDAcc_f1'], 'TDDef_Fav':row['TDDef_f1'], 'SubpM_Fav':row['SubpM_f1'],
            'Time_Sec_Cum_Fav':row['Time_Sec_Cum_f1'], 'Fight_Num_Fav':row['Fight_Num_f1'],
            
            'SLpM_Un':row['SLpM_f2'], 'SSAcc_Un':row['SSAcc_f2'], 'SSApM_Un':row['SSApM_f2'], 'SSDef_Un':row['SSDef_f2'],
            'TDpM_Un':row['TDpM_f2'], 'TDAcc_Un':row['TDAcc_f2'], 'TDDef_Un':row['TDDef_f2'], 'SubpM_Un':row['SubpM_f2'], 
            'Time_Sec_Cum_Un':row['Time_Sec_Cum_f2'], 'Fight_Num_Un':row['Fight_Num_f2'],
            
            
            
            'Nickname_Fav':row['Nickname_Fav'], 'Nickname_Un':row['Nickname_Un'], 'DOB_Fav':row['DOB_Fav'], 'DOB_Un':row['DOB_Un'],         
            'Betting_ID':row['Betting_ID'], 'Event_ID':row['Event_ID'], 'Fight_ID':row['Fight_ID'], 'Details':row['Details']
            
        }
        Final_df_organized_list.append(Final_df_organized_row)
        
    elif row['Fav_Fighter'].strip().lower() == row['Name_Fighter_2'].strip().lower() and row['Fighter_ID_Fav'].strip().lower() == row['Fighter_2_ID'].strip().lower() and row['Un_Fighter'].strip().lower() == row['Name_Fighter_1'].strip().lower() and row['Fighter_ID_Un'].strip().lower()==row['Fighter_1_ID'].strip().lower():
        
        
        Final_df_organized_row = {
            'Event_Name':row['Event_Name'], 'Date':row['Date'],'Fav_Fighter':row['Fav_Fighter'],
            'Un_Fighter':row['Un_Fighter'], 'Fighter_ID_Fav':row['Fighter_ID_Fav'], 'Fighter_ID_Un':row['Fighter_ID_Un'],
            'Result_Fav':row['Result_Fav'], 'Result_Un':row['Result_Un'], 'Round':row['Round'], 'Round_Format':row['Round_Format'],
            'Weight_Class':row['Weight_Class'], 'Time':row['Time'], 'Method':row['Method'], 'Height_Fav':row['Height_Fav'],
            'Reach_Fav':row['Reach_Fav'], 'Stance_Fav':row['Stance_Fav'], 'Height_Un':row['Height_Un'], 'Reach_Un':row['Reach_Un'],
            'Stance_Un':row['Stance_Un'], 'Age_At_Fight_Fav_Days':row['Age_At_Fight_Fav_Days'], 'Age_At_Fight_Un_Days':row['Age_At_Fight_Un_Days'],
            'Age_At_Fight_Fav_Years':row['Age_At_Fight_Fav_Years'], 'Age_At_Fight_Un_Years':row['Age_At_Fight_Un_Years'],
            'Age_Diff_Years':row['Age_Diff_Years'],'Age_Diff_Days':row['Age_Diff_Days'], 'Avg_Odds_Fav':row['Avg_Odds_Fav'],
            'Avg_Odds_Un':row['Avg_Odds_Un'],'Med_Odds_Fav':row['Med_Odds_Fav'], 'Med_Odds_Un':row['Med_Odds_Un'],
            'Impld_Prob_Avg_Fav':row['Impld_Prob_Avg_Fav'],'Impld_Prob_Avg_Un':row['Impld_Prob_Avg_Un'],
            'Impld_Prob_Med_Fav':row['Impld_Prob_Med_Fav'],'Impld_Prob_Med_Un':row['Impld_Prob_Med_Un'],
            'USodds_Fav_1':row['USodds_Fav_1'], 'USodds_Un_1':row['USodds_Un_1'], 'USodds_Fav_2':row['USodds_Fav_2'],
            'USodds_Un_2':row['USodds_Un_2'], 'USodds_Fav_3':row['USodds_Fav_3'], 'USodds_Un_3':row['USodds_Un_3'],
            'USodds_Fav_4':row['USodds_Fav_4'],'USodds_Un_4':row['USodds_Un_4'], 'USodds_Fav_5':row['USodds_Fav_5'],
            'USodds_Un_5':row['USodds_Un_5'],'Decodds_Fav_1':row['Decodds_Fav_1'],'Decodds_Un_1':row['Decodds_Un_1'],
            'Decodds_Fav_2':row['Decodds_Fav_2'], 'Decodds_Un_2':row['Decodds_Un_2'],'Decodds_Fav_3':row['Decodds_Fav_3'],
            'Decodds_Un_3':row['Decodds_Un_3'], 'Decodds_Fav_4':row['Decodds_Fav_4'], 'Decodds_Un_4':row['Decodds_Un_4'],
            'Decodds_Fav_5':row['Decodds_Fav_5'],'Decodds_Un_5':row['Decodds_Un_5'], 'KD_Fav':row['KD_Fav'], 'KD_Un':row['KD_Un'],
            'Pass_Fav':row['Pass_Fav'], 'Pass_Un':row['Pass_Un'], 'Rev_Fav':row['Rev_Fav'], 'Rev_Un':row['Rev_Un'],
            'Sig_Str_Fav':row['Sig_Str_Fav'],'Sig_Str_Un':row['Sig_Str_Un'], 'Sig_Str_Body_Fav':row['Sig_Str_Body_Fav'],
            'Sig_Str_Body_Un':row['Sig_Str_Body_Un'], 'Sig_Str_Clinch_Fav':row['Sig_Str_Clinch_Fav'],
            'Sig_Str_Clinch_Un':row['Sig_Str_Clinch_Un'], 'Sig_Str_Distance_Fav':row['Sig_Str_Distance_Fav'],
            'Sig_Str_Distance_Un':row['Sig_Str_Distance_Un'],'Sig_Str_Ground_Fav':row['Sig_Str_Ground_Fav'],
            'Sig_Str_Ground_Un':row['Sig_Str_Ground_Un'], 'Sig_Str_Head_Fav':row['Sig_Str_Head_Fav'],
            'Sig_Str_Head_Un':row['Sig_Str_Head_Un'], 'Sig_Str_Leg_Fav':row['Sig_Str_Leg_Fav'], 'Sig_Str_Leg_Un':row['Sig_Str_Leg_Un'],
            'Sig_Str_Pct_Fav':row['Sig_Str_Pct_Fav'], 'Sig_Str_Pct_Un':row['Sig_Str_Pct_Un'], 'Sub_Att_Fav':row['Sub_Att_Fav'],
            'Sub_Att_Un':row['Sub_Att_Un'], 'TD_Fav':row['TD_Fav'], 'TD_Un':row['TD_Un'], 'TD_Pct_Fav':row['TD_Pct_Fav'],
            'TD_Pct_Un':row['TD_Pct_Un'], 'Total_Str_Fav':row['Total_Str_Fav'], 'Total_Str_Un':row['Total_Str_Un'], 
            
            'SLpM_Fav':row['SLpM_f2'], 'SSAcc_Fav':row['SSAcc_f2'], 'SSApM_Fav':row['SSApM_f2'], 'SSDef_Fav':row['SSDef_f2'],
            'TDpM_Fav':row['TDpM_f2'], 'TDAcc_Fav':row['TDAcc_f2'], 'TDDef_Fav':row['TDDef_f2'], 'SubpM_Fav':row['SubpM_f2'],
            'Time_Sec_Cum_Fav':row['Time_Sec_Cum_f2'], 'Fight_Num_Fav':row['Fight_Num_f2'],
            
            'SLpM_Un':row['SLpM_f1'], 'SSAcc_Un':row['SSAcc_f1'], 'SSApM_Un':row['SSApM_f1'], 'SSDef_Un':row['SSDef_f1'],
            'TDpM_Un':row['TDpM_f1'], 'TDAcc_Un':row['TDAcc_f1'], 'TDDef_Un':row['TDDef_f1'], 'SubpM_Un':row['SubpM_f1'], 
            'Time_Sec_Cum_Un':row['Time_Sec_Cum_f1'], 'Fight_Num_Un':row['Fight_Num_f1'],
            
            
            
            'Nickname_Fav':row['Nickname_Fav'], 'Nickname_Un':row['Nickname_Un'], 'DOB_Fav':row['DOB_Fav'], 'DOB_Un':row['DOB_Un'],         
            'Betting_ID':row['Betting_ID'], 'Event_ID':row['Event_ID'], 'Fight_ID':row['Fight_ID'], 'Details':row['Details']
            
        }
        Final_df_organized_list.append(Final_df_organized_row)
        
        
    else:
        print(index)
        print('Fight Stat Data Not Available')

# %%
print(len(Final_df_organized_list))
# Out:
# 4208

# %%
Final_df_organized = pd.DataFrame(Final_df_organized_list)

# %%
Final_df_organized.head()
# Out:
#    Age_At_Fight_Fav_Days  Age_At_Fight_Fav_Years  Age_At_Fight_Un_Days  Age_At_Fight_Un_Years  Age_Diff_Days  Age_Diff_Years  Avg_Odds_Fav  Avg_Odds_Un                                         Betting_ID     DOB_Fav      DOB_Un       Date  Decodds_Fav_1  Decodds_Fav_2  Decodds_Fav_3  Decodds_Fav_4  Decodds_Fav_5  Decodds_Un_1  Decodds_Un_2  Decodds_Un_3  Decodds_Un_4  Decodds_Un_5                Details                                           Event_ID                       Event_Name      Fav_Fighter                                           Fight_ID  Fight_Num_Fav  Fight_Num_Un                                     Fighter_ID_Fav                                      Fighter_ID_Un Height_Fav Height_Un  Impld_Prob_Avg_Fav  Impld_Prob_Avg_Un  Impld_Prob_Med_Fav  Impld_Prob_Med_Un  KD_Fav  KD_Un  Med_Odds_Fav  Med_Odds_Un                Method            Nickname_Fav      Nickname_Un  Pass_Fav  Pass_Un Reach_Fav Reach_Un Result_Fav Result_Un  Rev_Fav  Rev_Un  Round       Round_Format  \
# ...

# %%
Final_df_organized = Final_df_organized[['Event_Name', 'Fav_Fighter', 'Un_Fighter','Fighter_ID_Fav','Fighter_ID_Un','Result_Fav','Result_Un',
                            'Round','Round_Format', 'Weight_Class', 'Time','Method','Height_Fav', 'Reach_Fav','Stance_Fav',
                            'Height_Un', 'Reach_Un', 'Stance_Un', 'Age_At_Fight_Fav_Days','Age_At_Fight_Fav_Years',
                            'Age_At_Fight_Un_Days', 'Age_At_Fight_Un_Years', 'Age_Diff_Days', 'Age_Diff_Years',            
                            'Avg_Odds_Fav','Avg_Odds_Un','Med_Odds_Fav',
                            'Med_Odds_Un','Impld_Prob_Avg_Fav','Impld_Prob_Avg_Un','Impld_Prob_Med_Fav','Impld_Prob_Med_Un',
                            'USodds_Fav_1','USodds_Un_1','USodds_Fav_2','USodds_Un_2','USodds_Fav_3','USodds_Un_3',
                            'USodds_Fav_4','USodds_Un_4','USodds_Fav_5','USodds_Un_5','Decodds_Fav_1','Decodds_Un_1',
                            'Decodds_Fav_2','Decodds_Un_2','Decodds_Fav_3','Decodds_Un_3','Decodds_Fav_4','Decodds_Un_4',
                            'Decodds_Fav_5','Decodds_Un_5','KD_Fav','KD_Un','Pass_Fav','Pass_Un','Rev_Fav','Rev_Un',
                            'Sig_Str_Fav','Sig_Str_Un','Sig_Str_Body_Fav','Sig_Str_Body_Un','Sig_Str_Clinch_Fav',
                            'Sig_Str_Clinch_Un','Sig_Str_Distance_Fav','Sig_Str_Distance_Un','Sig_Str_Ground_Fav',
                            'Sig_Str_Ground_Un','Sig_Str_Head_Fav','Sig_Str_Head_Un','Sig_Str_Leg_Fav','Sig_Str_Leg_Un',
                            'Sig_Str_Pct_Fav','Sig_Str_Pct_Un','Sub_Att_Fav','Sub_Att_Un','TD_Fav','TD_Un','TD_Pct_Fav',
                            'TD_Pct_Un','Total_Str_Fav','Total_Str_Un','SLpM_Fav', 'SSAcc_Fav', 'SSApM_Fav', 'SSDef_Fav',
                            'TDpM_Fav', 'TDAcc_Fav', 'TDDef_Fav', 'SubpM_Fav',
                            'Time_Sec_Cum_Fav', 'Fight_Num_Fav',
            
            'SLpM_Un', 'SSAcc_Un', 'SSApM_Un', 'SSDef_Un',
            'TDpM_Un', 'TDAcc_Un', 'TDDef_Un', 'SubpM_Un', 
            'Time_Sec_Cum_Un', 'Fight_Num_Un','Nickname_Fav','Nickname_Un','Betting_ID','Event_ID','Fight_ID','Details']]
Final_df_organized.head()
print(len(Final_df_organized))
# Out:
# 4208

# %%
Sig_Str_Com_fav = []
Sig_Str_Att_fav = []
Sig_Str_Com_un = []
Sig_Str_Att_un = []

Sig_Str_Body_Com_fav = []
Sig_Str_Body_Att_fav = []
Sig_Str_Body_Com_un = []
Sig_Str_Body_Att_un = []

Sig_Str_Clinch_Com_fav = []
Sig_Str_Clinch_Att_fav = []
Sig_Str_Clinch_Com_un = []
Sig_Str_Clinch_Att_un = []

Sig_Str_Distance_Com_fav = []
Sig_Str_Distance_Att_fav = []
Sig_Str_Distance_Com_un = []
Sig_Str_Distance_Att_un = []

Sig_Str_Ground_Com_fav = []
Sig_Str_Ground_Att_fav = []
Sig_Str_Ground_Com_un = []
Sig_Str_Ground_Att_un = []

Sig_Str_Head_Com_fav = []
Sig_Str_Head_Att_fav = []
Sig_Str_Head_Com_un = []
Sig_Str_Head_Att_un = []

Sig_Str_Leg_Com_fav = []
Sig_Str_Leg_Att_fav = []
Sig_Str_Leg_Com_un = []
Sig_Str_Leg_Att_un = []

TD_Com_fav = []
TD_Att_fav = []
TD_Com_un = []
TD_Att_un = []

Total_Str_Com_fav = []
Total_Str_Att_fav = []
Total_Str_Com_un = []
Total_Str_Att_un = []


for index,row in Final_df_organized.iterrows():
    SS_Com_fav = row['Sig_Str_Fav'].split("of")[0]
    Sig_Str_Com_fav.append(int(SS_Com_fav))
    SS_Att_fav = row['Sig_Str_Fav'].split("of")[1]
    Sig_Str_Att_fav.append(int(SS_Att_fav))
    SS_Com_un = row['Sig_Str_Un'].split("of")[0]
    Sig_Str_Com_un.append(int(SS_Com_un))
    SS_Att_un = row['Sig_Str_Un'].split("of")[1]
    Sig_Str_Att_un.append(int(SS_Att_un))
    
    SS_Body_Com_fav = row['Sig_Str_Body_Fav'].split("of")[0]
    Sig_Str_Body_Com_fav.append(int(SS_Body_Com_fav))
    SS_Body_Att_fav = row['Sig_Str_Body_Fav'].split("of")[1]
    Sig_Str_Body_Att_fav.append(int(SS_Body_Att_fav))
    SS_Body_Com_un = row['Sig_Str_Body_Un'].split("of")[0]
    Sig_Str_Body_Com_un.append(int(SS_Body_Com_un))
    SS_Body_Att_un = row['Sig_Str_Body_Un'].split("of")[1]
    Sig_Str_Body_Att_un.append(int(SS_Body_Att_un))
    
    SS_Clinch_Com_fav = row['Sig_Str_Clinch_Fav'].split("of")[0]
    Sig_Str_Clinch_Com_fav.append(int(SS_Clinch_Com_fav))
    SS_Clinch_Att_fav = row['Sig_Str_Clinch_Fav'].split("of")[1]
    Sig_Str_Clinch_Att_fav.append(int(SS_Clinch_Att_fav))
    SS_Clinch_Com_un = row['Sig_Str_Clinch_Un'].split("of")[0]
    Sig_Str_Clinch_Com_un.append(int(SS_Clinch_Com_un))
    SS_Clinch_Att_un = row['Sig_Str_Clinch_Un'].split("of")[1]
    Sig_Str_Clinch_Att_un.append(int(SS_Clinch_Att_un))
    
    SS_Distance_Com_fav = row['Sig_Str_Distance_Fav'].split("of")[0]
    Sig_Str_Distance_Com_fav.append(int(SS_Distance_Com_fav))
    SS_Distance_Att_fav = row['Sig_Str_Distance_Fav'].split("of")[1]
    Sig_Str_Distance_Att_fav.append(int(SS_Distance_Att_fav))
    SS_Distance_Com_un = row['Sig_Str_Distance_Un'].split("of")[0]
    Sig_Str_Distance_Com_un.append(int(SS_Distance_Com_un))
    SS_Distance_Att_un = row['Sig_Str_Distance_Un'].split("of")[1]
    Sig_Str_Distance_Att_un.append(int(SS_Distance_Att_un))
    
    SS_Ground_Com_fav = row['Sig_Str_Ground_Fav'].split("of")[0]
    Sig_Str_Ground_Com_fav.append(int(SS_Ground_Com_fav))
    SS_Ground_Att_fav = row['Sig_Str_Ground_Fav'].split("of")[1]
    Sig_Str_Ground_Att_fav.append(int(SS_Ground_Att_fav))
    SS_Ground_Com_un = row['Sig_Str_Ground_Un'].split("of")[0]
    Sig_Str_Ground_Com_un.append(int(SS_Ground_Com_un))
    SS_Ground_Att_un = row['Sig_Str_Ground_Un'].split("of")[1]
    Sig_Str_Ground_Att_un.append(int(SS_Ground_Att_un))
    
    SS_Head_Com_fav = row['Sig_Str_Head_Fav'].split("of")[0]
    Sig_Str_Head_Com_fav.append(int(SS_Head_Com_fav))
    SS_Head_Att_fav = row['Sig_Str_Head_Fav'].split("of")[1]
    Sig_Str_Head_Att_fav.append(int(SS_Head_Att_fav))
    SS_Head_Com_un = row['Sig_Str_Head_Un'].split("of")[0]
    Sig_Str_Head_Com_un.append(int(SS_Head_Com_un))
    SS_Head_Att_un = row['Sig_Str_Head_Un'].split("of")[1]
    Sig_Str_Head_Att_un.append(int(SS_Head_Att_un))
    
    SS_Leg_Com_fav = row['Sig_Str_Leg_Fav'].split("of")[0]
    Sig_Str_Leg_Com_fav.append(int(SS_Leg_Com_fav))
    SS_Leg_Att_fav = row['Sig_Str_Leg_Fav'].split("of")[1]
    Sig_Str_Leg_Att_fav.append(int(SS_Leg_Att_fav))
    SS_Leg_Com_un = row['Sig_Str_Leg_Un'].split("of")[0]
    Sig_Str_Leg_Com_un.append(int(SS_Leg_Com_un))
    SS_Leg_Att_un = row['Sig_Str_Leg_Un'].split("of")[1]
    Sig_Str_Leg_Att_un.append(int(SS_Leg_Att_un))
    
    TD_Com_fav0 = row['TD_Fav'].split("of")[0]
    TD_Com_fav.append(int(TD_Com_fav0))
    TD_Att_fav0 = row['TD_Fav'].split("of")[1]
    TD_Att_fav.append(int(TD_Att_fav0))
    TD_Com_un0 = row['TD_Un'].split("of")[0]
    TD_Com_un.append(int(TD_Com_un0))
    TD_Att_un0 = row['TD_Un'].split("of")[1]
    TD_Att_un.append(int(TD_Att_un0))
    
    Total_Str_com_fav = row['Total_Str_Fav'].split("of")[0]
    Total_Str_Com_fav.append(int(Total_Str_com_fav))
    Total_Str_att_fav = row['Total_Str_Fav'].split("of")[1]
    Total_Str_Att_fav.append(int(Total_Str_att_fav))
    Total_Str_com_un = row['Total_Str_Un'].split("of")[0]
    Total_Str_Com_un.append(int(Total_Str_com_un))
    Total_Str_att_un = row['Total_Str_Un'].split("of")[1]
    Total_Str_Att_un.append(int(Total_Str_att_un))

# %%
print(len(Sig_Str_Com_fav))
print(len(Sig_Str_Att_fav))
print(len(Sig_Str_Com_un))
print(len(Sig_Str_Att_un))

print(len(Sig_Str_Body_Com_fav))
print(len(Sig_Str_Body_Att_fav))
print(len(Sig_Str_Body_Com_un))
print(len(Sig_Str_Body_Att_un))

print(len(Sig_Str_Clinch_Com_fav))
print(len(Sig_Str_Clinch_Att_fav))
print(len(Sig_Str_Clinch_Com_un))
print(len(Sig_Str_Clinch_Att_un))

print(len(Sig_Str_Distance_Com_fav))
print(len(Sig_Str_Distance_Att_fav))
print(len(Sig_Str_Distance_Com_un))
print(len(Sig_Str_Distance_Att_un))

print(len(Sig_Str_Ground_Com_fav))
print(len(Sig_Str_Ground_Att_fav))
print(len(Sig_Str_Ground_Com_un))
print(len(Sig_Str_Ground_Att_un))

print(len(Sig_Str_Head_Com_fav))
print(len(Sig_Str_Head_Att_fav))
print(len(Sig_Str_Head_Com_un))
print(len(Sig_Str_Head_Att_un))

print(len(Sig_Str_Leg_Com_fav))
print(len(Sig_Str_Leg_Att_fav))
print(len(Sig_Str_Leg_Com_un))
print(len(Sig_Str_Leg_Att_un))

print(len(TD_Com_fav))
print(len(TD_Att_fav))
print(len(TD_Com_un))
print(len(TD_Att_un))

print(len(Total_Str_Com_fav))
print(len(Total_Str_Att_fav))
print(len(Total_Str_Com_un))
print(len(Total_Str_Att_un))
# Out:
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208
# 4208

# %%
Final_df_organized['Sig_Str_Com_Fav']=Sig_Str_Com_fav
Final_df_organized['Sig_Str_Att_Fav']=Sig_Str_Att_fav
Final_df_organized['Sig_Str_Com_Un']=Sig_Str_Com_un
Final_df_organized['Sig_Str_Att_Un']=Sig_Str_Att_un

Final_df_organized['Sig_Str_Body_Com_Fav']=Sig_Str_Body_Com_fav
Final_df_organized['Sig_Str_Body_Att_Fav']=Sig_Str_Body_Att_fav
Final_df_organized['Sig_Str_Body_Com_Un']=Sig_Str_Body_Com_un
Final_df_organized['Sig_Str_Body_Att_Un']=Sig_Str_Body_Att_un

Final_df_organized['Sig_Str_Clinch_Com_Fav']=Sig_Str_Clinch_Com_fav
Final_df_organized['Sig_Str_Clinch_Att_Fav']=Sig_Str_Clinch_Att_fav
Final_df_organized['Sig_Str_Clinch_Com_Un']=Sig_Str_Clinch_Com_un
Final_df_organized['Sig_Str_Clinch_Att_Un']=Sig_Str_Clinch_Att_un

Final_df_organized['Sig_Str_Distance_Com_Fav']=Sig_Str_Distance_Com_fav
Final_df_organized['Sig_Str_Distance_Att_Fav']=Sig_Str_Distance_Att_fav
Final_df_organized['Sig_Str_Distance_Com_Un']=Sig_Str_Distance_Com_un
Final_df_organized['Sig_Str_Distance_Att_Un']=Sig_Str_Distance_Att_un

Final_df_organized['Sig_Str_Ground_Com_Fav']=Sig_Str_Ground_Com_fav
Final_df_organized['Sig_Str_Ground_Att_Fav']=Sig_Str_Ground_Att_fav
Final_df_organized['Sig_Str_Ground_Com_Un']=Sig_Str_Ground_Com_un
Final_df_organized['Sig_Str_Ground_Att_Un']=Sig_Str_Ground_Att_un

Final_df_organized['Sig_Str_Head_Com_Fav']=Sig_Str_Head_Com_fav
Final_df_organized['Sig_Str_Head_Att_Fav']=Sig_Str_Head_Att_fav
Final_df_organized['Sig_Str_Head_Com_Un']=Sig_Str_Head_Com_un
Final_df_organized['Sig_Str_Head_Att_Un']=Sig_Str_Head_Att_un

Final_df_organized['Sig_Str_Leg_Com_Fav']=Sig_Str_Leg_Com_fav
Final_df_organized['Sig_Str_Leg_Att_Fav']=Sig_Str_Leg_Att_fav
Final_df_organized['Sig_Str_Leg_Com_Un']=Sig_Str_Leg_Com_un
Final_df_organized['Sig_Str_Leg_Att_Un']=Sig_Str_Leg_Att_un

Final_df_organized['TD_Com_Fav']=TD_Com_fav
Final_df_organized['TD_Att_Fav']=TD_Att_fav
Final_df_organized['TD_Com_Un']=TD_Com_un
Final_df_organized['TD_Att_Un']=TD_Att_un

Final_df_organized['Total_Str_Com_Fav']=Total_Str_Com_fav
Final_df_organized['Total_Str_Att_Fav']=Total_Str_Att_fav
Final_df_organized['Total_Str_Com_Un']=Total_Str_Com_un
Final_df_organized['Total_Str_Att_Un']=Total_Str_Att_un

# %%
Final_df_organized.describe()
# Out:
#              Round  Age_At_Fight_Fav_Days  Age_At_Fight_Fav_Years  Age_At_Fight_Un_Days  Age_At_Fight_Un_Years  Age_Diff_Days  Age_Diff_Years  Avg_Odds_Fav  Avg_Odds_Un  Med_Odds_Fav  Med_Odds_Un  Impld_Prob_Avg_Fav  Impld_Prob_Avg_Un  Impld_Prob_Med_Fav  Impld_Prob_Med_Un  USodds_Fav_1  USodds_Un_1  USodds_Fav_2  USodds_Un_2  USodds_Fav_3  USodds_Un_3  USodds_Fav_4  USodds_Un_4  USodds_Fav_5  USodds_Un_5  Decodds_Fav_1  Decodds_Un_1  Decodds_Fav_2  Decodds_Un_2  Decodds_Fav_3  Decodds_Un_3  Decodds_Fav_4  Decodds_Un_4  Decodds_Fav_5  Decodds_Un_5       KD_Fav        KD_Un     Pass_Fav      Pass_Un      Rev_Fav       Rev_Un  Sub_Att_Fav   Sub_Att_Un     SLpM_Fav    SSAcc_Fav    SSApM_Fav    SSDef_Fav     TDpM_Fav    TDAcc_Fav    TDDef_Fav    SubpM_Fav  Time_Sec_Cum_Fav  Fight_Num_Fav      SLpM_Un     SSAcc_Un     SSApM_Un     SSDef_Un      TDpM_Un     TDAcc_Un     TDDef_Un     SubpM_Un  Time_Sec_Cum_Un  Fight_Num_Un  Sig_Str_Com_Fav  Sig_Str_Att_Fav  Sig_Str_Com_Un  Sig_Str_Att_Un  \
# ...

# %%
Time_Secs = []
for index, row in Final_df_organized.iterrows():
    if row['Round'] == 1: 
        m,s = row['Time'].split(':')
        secs = dt.timedelta(minutes=int(m),seconds=int(s)).total_seconds()
        Time_Secs.append(secs)
    elif row['Round'] == 2:
        m,s = row['Time'].split(':')
        secs = dt.timedelta(minutes=int(m),seconds=int(s)).total_seconds()
        secs = secs + (5*60)
        Time_Secs.append(secs)
    elif row['Round'] == 3:
        m,s = row['Time'].split(':')
        secs = dt.timedelta(minutes=int(m),seconds=int(s)).total_seconds()
        secs = secs + (10*60)
        Time_Secs.append(secs)
    elif row['Round'] == 4:
        m,s = row['Time'].split(':')
        secs = dt.timedelta(minutes=int(m),seconds=int(s)).total_seconds()
        secs = secs + (15*60)
        Time_Secs.append(secs)
    elif row['Round'] == 5:
        m,s = row['Time'].split(':')
        secs = dt.timedelta(minutes=int(m),seconds=int(s)).total_seconds()
        secs = secs + (20*60)
        Time_Secs.append(secs)

# %%
print(len(Final_df_organized))
print(len(Time_Secs))
# Out:
# 4208
# 4208

# %%
Final_df_organized['Time_Secs'] = Time_Secs

# %%
Final_df_organized['Time_Secs'].describe()
# Out:
# count    4208.000000
# mean      642.442966
# std       356.621595
# min         5.000000
# 25%       287.750000
# 50%       872.000000
# 75%       900.000000
# max      1500.000000
# Name: Time_Secs, dtype: float64

# %%
Height_Inches_fav = []
for index,row in Final_df_organized.iterrows():
    H_feet_fav = row['Height_Fav'].split("'")[0]
    H_inch_fav = row['Height_Fav'].split("'")[1].split("\"")[0]
    H_inches_fav = int(H_feet_fav) * 12 + int(H_inch_fav)
    Height_Inches_fav.append(H_inches_fav)

# %%
Height_Inches_un = []
for index,row in Final_df_organized.iterrows():
    H_feet_un = row['Height_Un'].split("'")[0]
    H_inch_un = row['Height_Un'].split("'")[1].split("\"")[0]
    H_inches_un = int(H_feet_un) * 12 + int(H_inch_un)
    Height_Inches_un.append(H_inches_un)

# %%
Reach_Inches_fav = []
for index,row in Final_df_organized.iterrows():
    R_inch_fav = row['Reach_Fav'].split('"')[0]
    Reach_Inches_fav.append(R_inch_fav)

# %%
print(len(Reach_Inches_fav))
# Out:
# 4208

# %%
Reach_Inches_un = []
for index,row in Final_df_organized.iterrows():
    R_inch_un = row['Reach_Un'].split('"')[0]
    Reach_Inches_un.append(R_inch_un)

# %%
print(len(Reach_Inches_un))
# Out:
# 4208

# %%
Final_df_organized['Height_Inches_Fav'] = Height_Inches_fav
Final_df_organized['Height_Inches_Un'] = Height_Inches_un
Final_df_organized['Reach_Inches_Fav'] = Reach_Inches_fav
Final_df_organized['Reach_Inches_Un'] = Reach_Inches_un

# %%
Final_df_organized['Height_Inches_Fav'].describe()
# Out:
# count    4208.000000
# mean       70.369297
# std         3.489879
# min        60.000000
# 25%        68.000000
# 50%        71.000000
# 75%        73.000000
# max        83.000000
# Name: Height_Inches_Fav, dtype: float64

# %%
Final_df_organized['Height_Inches_Un'].describe()
# Out:
# count    4208.000000
# mean       70.278517
# std         3.386223
# min        60.000000
# 25%        68.000000
# 50%        70.000000
# 75%        73.000000
# max        83.000000
# Name: Height_Inches_Un, dtype: float64

# %%
Final_df_organized['Reach_Inches_Fav'] = Final_df_organized['Reach_Inches_Fav'].astype(float)
Final_df_organized['Reach_Inches_Fav'].describe()
# Out:
# count    4208.000000
# mean       72.243584
# std         4.213246
# min        60.000000
# 25%        70.000000
# 50%        72.000000
# 75%        75.000000
# max        84.000000
# Name: Reach_Inches_Fav, dtype: float64

# %%
Final_df_organized['Reach_Inches_Un'] = Final_df_organized['Reach_Inches_Un'].astype(float)
Final_df_organized['Reach_Inches_Un'].describe()
# Out:
# count    4208.000000
# mean       71.932034
# std         4.013321
# min        60.000000
# 25%        70.000000
# 50%        72.000000
# 75%        75.000000
# max        84.000000
# Name: Reach_Inches_Un, dtype: float64

# %% [markdown]
# ## Create variables to match 'fighter stats' dataset
# ### The website the data were scraped from frequently updates fighter career statistcs that will be used, in part, as the input to the prediciton model.
# #### SLpM -- Significant Strikes landed per minute. Computed by taking the number of successful ((Sig. Strs.) / (num of secs in that fight)) * (60)
# #### SSAcc -- Significant Strike Accuracy. (Num SS Completed) / (Num SS Attempted)
# #### SSApM -- Significant Strikes Absorbed per Minute ((Num of opponent SS's landed) / (num of secs in that fight)) * (60)
# #### SSDef -- Significant Strike Defense (% of opponent strikes that did not land)
# #### TDpM -- Takedowns completed per minute ((Num of Takedowns) / (num of secs in that fight)) * (60)
# #### TDAcc -- Takedown Accuracy (% of takedowns completed)
# #### TDDef -- Takedown Defense (% of opponenet takedowns that did not land)
# #### SubpM -- Submissions attempted per minute ((num of sub atts) / (num of secs in fight)) * (60)

# %%
# df['SLpM_Fav'] = (df['Sig_Str_Com_Fav'] / df['Time_Secs']) * 60
# df['SLpM_Un'] = (df['Sig_Str_Com_Un'] / df['Time_Secs']) * 60

# df['SSAcc_Fav'] = df['Sig_Str_Com_Fav'] / df['Sig_Str_Att_Fav']
# df['SSAcc_Un'] = df['Sig_Str_Com_Un'] / df['Sig_Str_Att_Un']

# df['SSApM_Fav'] = (df['Sig_Str_Com_Un'] / df['Time_Secs']) * 60
# df['SSApM_Un'] = (df['Sig_Str_Com_Fav'] / df['Time_Secs']) * 60

# df['SSDef_Fav'] = 1 - (df['Sig_Str_Com_Un'] / df['Sig_Str_Att_Un'])
# df['SSDef_Un'] = 1 - ( df['Sig_Str_Com_Fav'] / df['Sig_Str_Att_Fav'])

# df['TDpM_Fav'] = (df['TD_Com_Fav'] / df['Time_Secs']) * 60
# df['TDpM_Un'] = (df['TD_Com_Un'] / df['Time_Secs']) * 60

# df['TDAcc_Fav'] = df['TD_Com_Fav'] / df['TD_Att_Fav']
# df['TDAcc_Un'] = df['TD_Com_Un'] / df['TD_Att_Un']

# df['TDDef_Fav'] = 1 - (df['TD_Com_Un'] / df['TD_Att_Un'])
# df['TDDef_Un'] = 1 - (df['TD_Com_Fav'] / df['TD_Att_Fav'])

# df['SubpM_Fav'] = (df['Sub_Att_Fav'] / df['Time_Secs']) * 60
# df['SubpM_Un'] = (df['Sub_Att_Un'] / df['Time_Secs']) * 60

# %%
Final_df_organized.head()
# Out:
#                         Event_Name      Fav_Fighter        Un_Fighter                                     Fighter_ID_Fav                                      Fighter_ID_Un Result_Fav Result_Un  Round       Round_Format                 Weight_Class  Time                Method Height_Fav Reach_Fav Stance_Fav Height_Un Reach_Un Stance_Un  Age_At_Fight_Fav_Days  Age_At_Fight_Fav_Years  Age_At_Fight_Un_Days  Age_At_Fight_Un_Years  Age_Diff_Days  Age_Diff_Years  Avg_Odds_Fav  Avg_Odds_Un  Med_Odds_Fav  Med_Odds_Un  Impld_Prob_Avg_Fav  Impld_Prob_Avg_Un  Impld_Prob_Med_Fav  Impld_Prob_Med_Un  USodds_Fav_1  USodds_Un_1  USodds_Fav_2  USodds_Un_2  USodds_Fav_3  USodds_Un_3  USodds_Fav_4  USodds_Un_4  USodds_Fav_5  USodds_Un_5  Decodds_Fav_1  Decodds_Un_1  Decodds_Fav_2  Decodds_Un_2  Decodds_Fav_3  Decodds_Un_3  Decodds_Fav_4  Decodds_Un_4  Decodds_Fav_5  Decodds_Un_5  KD_Fav  KD_Un  Pass_Fav  Pass_Un  Rev_Fav  Rev_Un Sig_Str_Fav Sig_Str_Un Sig_Str_Body_Fav Sig_Str_Body_Un Sig_Str_Clinch_Fav 
# ...

# %% [markdown]
# ## All Features are computed by taking the difference between fav value and underdog value

# %%
Final_df_organized['Avg_Odds_Diff'] = Final_df_organized['Avg_Odds_Fav'] - Final_df_organized['Avg_Odds_Un']
Final_df_organized['Med_Odds_Diff'] = Final_df_organized['Med_Odds_Fav'] - Final_df_organized['Med_Odds_Un']
Final_df_organized['Impld_Prob_Avg_Diff'] =Final_df_organized['Impld_Prob_Avg_Fav'] - Final_df_organized['Impld_Prob_Avg_Un']
Final_df_organized['Impld_Prob_Med_Diff'] =Final_df_organized['Impld_Prob_Med_Fav'] - Final_df_organized['Impld_Prob_Med_Un']
Final_df_organized['Height_Diff'] = Final_df_organized['Height_Inches_Fav'] - Final_df_organized['Height_Inches_Un']
Final_df_organized['Reach_Diff'] = Final_df_organized['Reach_Inches_Fav'] - Final_df_organized['Reach_Inches_Un']
Final_df_organized['SLpM_Diff'] = Final_df_organized['SLpM_Fav'] - Final_df_organized['SLpM_Un']
Final_df_organized['SSAcc_Diff'] = Final_df_organized['SSAcc_Fav'] - Final_df_organized['SSAcc_Un']
Final_df_organized['SSApM_Diff'] = Final_df_organized['SSApM_Fav'] - Final_df_organized['SSApM_Un']
Final_df_organized['SSDef_Diff'] = Final_df_organized['SSDef_Fav'] - Final_df_organized['SSDef_Un']
Final_df_organized['TDpM_Diff'] = Final_df_organized['TDpM_Fav'] - Final_df_organized['TDpM_Un']
Final_df_organized['TDAcc_Diff'] = Final_df_organized['TDAcc_Fav'] - Final_df_organized['TDAcc_Un']
Final_df_organized['TDDef_Diff'] = Final_df_organized['TDDef_Fav'] - Final_df_organized['TDDef_Un']
Final_df_organized['SubpM_Diff'] = Final_df_organized['SubpM_Fav'] - Final_df_organized['SubpM_Un']

# %%
Final_df_organized.head()
# Out:
#                         Event_Name      Fav_Fighter        Un_Fighter                                     Fighter_ID_Fav                                      Fighter_ID_Un Result_Fav Result_Un  Round       Round_Format                 Weight_Class  Time                Method Height_Fav Reach_Fav Stance_Fav Height_Un Reach_Un Stance_Un  Age_At_Fight_Fav_Days  Age_At_Fight_Fav_Years  Age_At_Fight_Un_Days  Age_At_Fight_Un_Years  Age_Diff_Days  Age_Diff_Years  Avg_Odds_Fav  Avg_Odds_Un  Med_Odds_Fav  Med_Odds_Un  Impld_Prob_Avg_Fav  Impld_Prob_Avg_Un  Impld_Prob_Med_Fav  Impld_Prob_Med_Un  USodds_Fav_1  USodds_Un_1  USodds_Fav_2  USodds_Un_2  USodds_Fav_3  USodds_Un_3  USodds_Fav_4  USodds_Un_4  USodds_Fav_5  USodds_Un_5  Decodds_Fav_1  Decodds_Un_1  Decodds_Fav_2  Decodds_Un_2  Decodds_Fav_3  Decodds_Un_3  Decodds_Fav_4  Decodds_Un_4  Decodds_Fav_5  Decodds_Un_5  KD_Fav  KD_Un  Pass_Fav  Pass_Un  Rev_Fav  Rev_Un Sig_Str_Fav Sig_Str_Un Sig_Str_Body_Fav Sig_Str_Body_Un Sig_Str_Clinch_Fav 
# ...

# %%
Final_df_organized.describe()
# Out:
#              Round  Age_At_Fight_Fav_Days  Age_At_Fight_Fav_Years  Age_At_Fight_Un_Days  Age_At_Fight_Un_Years  Age_Diff_Days  Age_Diff_Years  Avg_Odds_Fav  Avg_Odds_Un  Med_Odds_Fav  Med_Odds_Un  Impld_Prob_Avg_Fav  Impld_Prob_Avg_Un  Impld_Prob_Med_Fav  Impld_Prob_Med_Un  USodds_Fav_1  USodds_Un_1  USodds_Fav_2  USodds_Un_2  USodds_Fav_3  USodds_Un_3  USodds_Fav_4  USodds_Un_4  USodds_Fav_5  USodds_Un_5  Decodds_Fav_1  Decodds_Un_1  Decodds_Fav_2  Decodds_Un_2  Decodds_Fav_3  Decodds_Un_3  Decodds_Fav_4  Decodds_Un_4  Decodds_Fav_5  Decodds_Un_5       KD_Fav        KD_Un     Pass_Fav      Pass_Un      Rev_Fav       Rev_Un  Sub_Att_Fav   Sub_Att_Un     SLpM_Fav    SSAcc_Fav    SSApM_Fav    SSDef_Fav     TDpM_Fav    TDAcc_Fav    TDDef_Fav    SubpM_Fav  Time_Sec_Cum_Fav  Fight_Num_Fav      SLpM_Un     SSAcc_Un     SSApM_Un     SSDef_Un      TDpM_Un     TDAcc_Un     TDDef_Un     SubpM_Un  Time_Sec_Cum_Un  Fight_Num_Un  Sig_Str_Com_Fav  Sig_Str_Att_Fav  Sig_Str_Com_Un  Sig_Str_Att_Un  \
# ...

# %%
Final_df_organized.to_csv('Final_df.csv', index=False)
